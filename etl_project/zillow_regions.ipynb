# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pprint import pprint
import requests
import statistics
import time
import quandl  #Used for data import
quandl.ApiConfig.api_key = 'vxSYNGB-9owcVsRx_SEF'
pd.set_option('display.max_colwidth', None)

# %%
zillow_regions=quandl.get_table('ZILLOW/REGIONS',paginate=True)
zillow_regions.head()
# Out:
#       region_id region_type                                           region
# None
# 0         99999         zip   98847; WA; Wenatchee; Chelan County; Peshastin
# 1         99998         zip              98846; WA; Okanogan County; Pateros
# 2         99997         zip  98845; WA; Wenatchee; Douglas County; Palisades
# 3         99996         zip             98844; WA; Okanogan County; Oroville
# 4         99995         zip     98843; WA; Wenatchee; Douglas County; Orondo
# ...         ...         ...                                              ...
# 79169    100000         zip      98848; WA; Moses Lake; Grant County; Quincy
# 79170     10000        city                  Bloomington; MD; Garrett County
# 79171      1000      county                      Echols County; GA; Valdosta
# 79172       100      county               Bibb County; AL; Birmingham-Hoover
# 79173        10       state                                     Colorado; CO
#
# [79174 rows x 3 columns]

# %%
# zillow_regions['zipcode'] = 'NAN'

# new = zillow_regions['region'].str.split(';',n = 4, expand=True)
# for i in range(len(zillow_regions)):
#     if new[0][i].isdigit():
#         zillow_regions['zipcode'][i] = new[0][i]


zillow_regions['zipcode'] = 'NAN'
zillow_regions['state'] = 'NAN'
zillow_regions['metro'] = 'NAN'
zillow_regions['city'] = 'NAN'
zillow_regions['county'] = 'NAN'
zillow_regions['neighborhood'] = 'NAN'

for column in range(len(zillow_regions)):
        
    new = zillow_regions['region'].str.split(";", n = -1, expand = True)
#     if new[0][column].isdigit():
#         zillow_regions['zipcode'][column] = new[0][column]
        
#         zillow_regions["zipcode"]= new[0]
    if len(new[0][column]) == 2:
        zillow_regions['state'][column] = new[1][column]
#     if '-' in new:
#         zillow_regions['metro'] = new[2]  
#     else:
#         zillow_regions['city'] = new[2]
#     if 'county' in new:
#         zillow_regions["county"] = new[3]
#     else:
#         zillow_regions['neighborhood'] = new[4]  
        
#print(column)
#if zillow_regions[column].str.split(';').str.len() == 5:
#new = zillow_regions['region'].str.split(';', n = -1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-aa0f2e051f9a> in <module>
#      16 for column in range(len(zillow_regions)):
#      17
# ---> 18     new = zillow_regions['region'].str.split(";", n = -1, expand = True)
#      19 #     if new[0][column].isdigit():
#      20 #         zillow_regions['zipcode'][column] = new[0][column]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in wrapper(self, *args, **kwargs)
#    1999                 )
#    2000                 raise TypeError(msg)
# -> 2001             return func(self, *args, **kwargs)
#    2002
#    2003         wrapper.__name__ = func_name
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in split(self, pat, n, expand)
#    2687     @forbid_nonstring_types(["bytes"])
#    2688     def split(self, pat=None, n=-1, expand=False):
# -> 2689         result = str_split(self._parent, pat, n=n)
#    2690         return self._wrap_result(result, expand=expand, returns_string=expand)
#    2691
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in str_split(arr, pat, n)
#    1540             regex = re.compile(pat)
#    1541             f = lambda x: regex.split(x, maxsplit=n)
# -> 1542     res = _na_map(f, arr)
#    1543     return res
#    1544
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in _na_map(f, arr, na_result, dtype)
#     128     if na_result is None:
#     129         na_result = np.nan
# --> 130     return _map_object(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     131
#     132
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in _map_object(f, arr, na_mask, na_value, dtype)
#     213         convert = not np.all(mask)
#     214         try:
# --> 215             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#     216         except (TypeError, AttributeError) as e:
#     217             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/strings.py in <lambda>(x)
#    1534             if n is None or n == 0:
#    1535                 n = -1
# -> 1536             f = lambda x: x.split(pat, n)
#    1537         else:
#    1538             if n is None or n == -1:
#
# KeyboardInterrupt:

# %%
new = zillow_regions['region'].str.split(";", n = -1, expand = True)

# for split in new:
#     print(split)
# for column in range(len(zillow_regions)):
#     for word in new:
#         print(word)
#         if len(word) == 2:
#         zillow_regions["state"]= new[1]
range(len(zillow_regions))
#zillow_regions
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
zillow_regions.head()
# Out:
#      region_id region_type                                           region
# None
# 0        99999         zip   98847; WA; Wenatchee; Chelan County; Peshastin
# 1        99998         zip              98846; WA; Okanogan County; Pateros
# 2        99997         zip  98845; WA; Wenatchee; Douglas County; Palisades
# 3        99996         zip             98844; WA; Okanogan County; Oroville
# 4        99995         zip     98843; WA; Wenatchee; Douglas County; Orondo
