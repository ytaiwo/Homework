# %% [markdown]
# ## Screenshots of Code

# %% [markdown]
# ![Screen%20Shot%202021-07-28%20at%2010.20.44%20PM.png](attachment:Screen%20Shot%202021-07-28%20at%2010.20.44%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-28%20at%2010.20.53%20PM.png](attachment:Screen%20Shot%202021-07-28%20at%2010.20.53%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-28%20at%2010.22.59%20PM.png](attachment:Screen%20Shot%202021-07-28%20at%2010.22.59%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-28%20at%2010.23.44%20PM.png](attachment:Screen%20Shot%202021-07-28%20at%2010.23.44%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-28%20at%2010.23.59%20PM.png](attachment:Screen%20Shot%202021-07-28%20at%2010.23.59%20PM.png)

# %% [markdown]
# ![Screen%20Shot%202021-07-28%20at%2010.24.11%20PM.png](attachment:Screen%20Shot%202021-07-28%20at%2010.24.11%20PM.png)

# %% [markdown]
# 2.	What kind of API did you build? What types of APIs are there? Why are APIs important?!

# %% [markdown]
# I built a WEB API. The types of API are Open, Internal, Partner, and composite. Also REST, JSON, and SOAP. APIs are important because they help with communication between users and also a computer program can be used by another computer program.
